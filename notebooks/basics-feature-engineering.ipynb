# %% [markdown]
# # Feature Engineering Basics
#
# Feature engineering is the art of transforming raw data into features that better represent the underlying problem to machine learning models. This notebook explores four fundamental techniques:
#
# 1. **Normalization** - Scaling features to a fixed range (typically [0, 1])
# 2. **Standardization** - Transforming features to have zero mean and unit variance
# 3. **One-Hot Encoding** - Converting categorical variables into binary vectors
# 4. **Binning** - Grouping continuous values into discrete intervals
#
# These techniques help machine learning algorithms work more effectively by putting features on comparable scales and handling different data types appropriately.

# %% [markdown]
# ## Setup
#
# Import the libraries we'll need for our feature engineering exploration.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder

# Set style for better visualizations
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# # 1. Normalization (Min-Max Scaling)
#
# ## Why Normalize?
#
# Imagine you're building a model to predict house prices using features like:
# - Square footage: 500-5000 sq ft
# - Number of bedrooms: 1-6
# - Age: 0-100 years
#
# The square footage dominates the other features simply because of its scale. Normalization solves this by transforming all features to the same range, typically [0, 1].

# %% [markdown]
# ## The Formula
#
# Min-Max normalization transforms a value $x$ to a new value $x'$ in the range [0, 1]:
#
# $$x' = \frac{x - x_{min}}{x_{max} - x_{min}}$$
#
# Where:
# - $x_{min}$ is the minimum value in the feature
# - $x_{max}$ is the maximum value in the feature
#
# The minimum value maps to 0, the maximum to 1, and everything else scales proportionally in between.

# %% [markdown]
# ## Simple Example: Manual Implementation
#
# Let's normalize a simple array of test scores manually to understand the process.

# %%
# Original test scores
scores = np.array([45, 67, 89, 92, 78, 55, 61])

print(f"Original scores: {scores}")
print(f"Min: {scores.min()}, Max: {scores.max()}")
# Out:
# Original scores: [45 67 89 92 78 55 61]
# Min: 45, Max: 92

# %% [markdown]
# Apply the normalization formula step by step.

# %%
# Manual normalization
min_score = scores.min()
max_score = scores.max()

normalized_scores = (scores - min_score) / (max_score - min_score)

print(f"Normalized scores: {normalized_scores}")
print(f"New min: {normalized_scores.min():.2f}, New max: {normalized_scores.max():.2f}")
# Out:
# Normalized scores: [0.         0.46808511 0.93617021 1.         0.70212766 0.21276596
#  0.34042553]
# New min: 0.00, New max: 1.00

# %% [markdown]
# ## Visualizing the Transformation
#
# Let's see how normalization changes the scale while preserving the relative relationships.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Original scores
ax1.bar(range(len(scores)), scores, color='steelblue')
ax1.set_xlabel('Student')
ax1.set_ylabel('Score')
ax1.set_title('Original Scores')
ax1.set_ylim([0, 100])

# Normalized scores
ax2.bar(range(len(normalized_scores)), normalized_scores, color='coral')
ax2.set_xlabel('Student')
ax2.set_ylabel('Normalized Score')
ax2.set_title('Normalized Scores [0, 1]')
ax2.set_ylim([0, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Real-World Example: House Features
#
# Let's create a dataset with features on vastly different scales and see how normalization helps.

# %%
# Create synthetic house data
houses = pd.DataFrame({
    'sqft': [850, 1200, 2400, 1800, 3200, 950],
    'bedrooms': [1, 2, 4, 3, 5, 2],
    'age': [15, 5, 30, 12, 2, 8]
})

print("Original House Data:")
print(houses)
print("\nStatistics:")
print(houses.describe())
# Out:
# Original House Data:
#    sqft  bedrooms  age
# 0   850         1   15
# 1  1200         2    5
# 2  2400         4   30
# 3  1800         3   12
# 4  3200         5    2
# 5   950         2    8
#
# Statistics:
#               sqft  bedrooms       age
# count     6.000000  6.000000   6.00000
# mean   1733.333333  2.833333  12.00000
# std     925.022522  1.471960   9.97998
# min     850.000000  1.000000   2.00000
# 25%    1012.500000  2.000000   5.75000
# 50%    1500.000000  2.500000  10.00000
# 75%    2250.000000  3.750000  14.25000
# max    3200.000000  5.000000  30.00000

# %% [markdown]
# Use sklearn's MinMaxScaler for convenient normalization of multiple features.

# %%
# Normalize using sklearn
scaler = MinMaxScaler()
houses_normalized = pd.DataFrame(
    scaler.fit_transform(houses),
    columns=houses.columns
)

print("Normalized House Data:")
print(houses_normalized)
print("\nAll features now in [0, 1] range!")
# Out:
# Normalized House Data:
#        sqft  bedrooms       age
# 0  0.000000      0.00  0.464286
# 1  0.148936      0.25  0.107143
# 2  0.659574      0.75  1.000000
# 3  0.404255      0.50  0.357143
# 4  1.000000      1.00  0.000000
# 5  0.042553      0.25  0.214286
#
# All features now in [0, 1] range!

# %% [markdown]
# Visualize the dramatic effect of normalization on features with different scales.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Original data
houses.plot(kind='box', ax=ax1)
ax1.set_title('Original Features (Different Scales)')
ax1.set_ylabel('Value')

# Normalized data
houses_normalized.plot(kind='box', ax=ax2)
ax2.set_title('Normalized Features [0, 1]')
ax2.set_ylabel('Normalized Value')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## When to Use Normalization
#
# **Best for:**
# - Neural networks (especially with sigmoid/tanh activations)
# - Distance-based algorithms (K-NN, K-Means)
# - Image data (pixel values 0-255 → 0-1)
#
# **Limitation:** Sensitive to outliers since they determine the min and max values.

# %% [markdown]
# # 2. Standardization (Z-Score Normalization)
#
# ## Why Standardize?
#
# While normalization scales to a fixed range, standardization transforms data to have **zero mean** and **unit variance**. This is particularly useful when:
# - Your features have different units
# - You want to preserve information about outliers
# - Your algorithm assumes normally distributed data

# %% [markdown]
# ## The Formula
#
# Standardization (z-score) transforms a value $x$ to $x'$ using:
#
# $$x' = \frac{x - \mu}{\sigma}$$
#
# Where:
# - $\mu$ is the mean of the feature
# - $\sigma$ is the standard deviation of the feature
#
# The result tells you how many standard deviations away from the mean each value is.

# %% [markdown]
# ## Simple Example: Manual Implementation
#
# Let's standardize our test scores to see the difference from normalization.

# %%
# Same test scores as before
scores = np.array([45, 67, 89, 92, 78, 55, 61])

print(f"Original scores: {scores}")
print(f"Mean: {scores.mean():.2f}, Std: {scores.std():.2f}")
# Out:
# Original scores: [45 67 89 92 78 55 61]
# Mean: 69.57, Std: 16.25

# %% [markdown]
# Apply the standardization formula manually.

# %%
# Manual standardization
mean_score = scores.mean()
std_score = scores.std()

standardized_scores = (scores - mean_score) / std_score

print(f"Standardized scores: {standardized_scores}")
print(f"New mean: {standardized_scores.mean():.10f}, New std: {standardized_scores.std():.2f}")
# Out:
# Standardized scores: [-1.51238381 -0.15827272  1.19583836  1.38048987  0.51878282 -0.89687877
#  -0.52757575]
# New mean: 0.0000000000, New std: 1.00

# %% [markdown]
# ## Interpreting Z-Scores
#
# A z-score tells you how unusual a value is:
# - z = 0: exactly at the mean
# - z = 1: one standard deviation above mean
# - z = -2: two standard deviations below mean
#
# Let's see which students performed better or worse than average.

# %%
interpretation = pd.DataFrame({
    'Student': range(len(scores)),
    'Original Score': scores,
    'Z-Score': standardized_scores,
    'Interpretation': [
        f"{abs(z):.2f} std {'above' if z > 0 else 'below'} mean"
        for z in standardized_scores
    ]
})

print(interpretation.to_string(index=False))
# Out:
#  Student  Original Score   Z-Score      Interpretation
#        0              45 -1.512384 1.51 std below mean
#        1              67 -0.158273 0.16 std below mean
#        2              89  1.195838 1.20 std above mean
#        3              92  1.380490 1.38 std above mean
#        4              78  0.518783 0.52 std above mean
#        5              55 -0.896879 0.90 std below mean
#        6              61 -0.527576 0.53 std below mean

# %% [markdown]
# ## Visualizing Standardization
#
# Compare the distribution shape before and after standardization.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Original scores distribution
ax1.hist(scores, bins=7, color='steelblue', alpha=0.7, edgecolor='black')
ax1.axvline(scores.mean(), color='red', linestyle='--', linewidth=2, label=f'Mean = {scores.mean():.1f}')
ax1.set_xlabel('Score')
ax1.set_ylabel('Frequency')
ax1.set_title('Original Scores')
ax1.legend()

# Standardized scores distribution
ax2.hist(standardized_scores, bins=7, color='coral', alpha=0.7, edgecolor='black')
ax2.axvline(standardized_scores.mean(), color='red', linestyle='--', linewidth=2, label=f'Mean ≈ 0')
ax2.set_xlabel('Z-Score')
ax2.set_ylabel('Frequency')
ax2.set_title('Standardized Scores (Z-Scores)')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Standardization with sklearn
#
# Apply standardization to our house dataset using StandardScaler.

# %%
# Standardize house features
scaler_std = StandardScaler()
houses_standardized = pd.DataFrame(
    scaler_std.fit_transform(houses),
    columns=houses.columns
)

print("Standardized House Data:")
print(houses_standardized)
print("\nMeans (should be ≈ 0):")
print(houses_standardized.mean())
print("\nStandard Deviations (should be ≈ 1):")
print(houses_standardized.std())
# Out:
# Standardized House Data:
#        sqft  bedrooms       age
# 0 -1.046075 -1.364382  0.329293
# 1 -0.631593 -0.620174 -0.768350
# 2  0.789491  0.868243  1.975757
# 3  0.078949  0.124035  0.000000
# 4  1.736880  1.612452 -1.097643
# 5 -0.927652 -0.620174 -0.439057
#
# Means (should be ≈ 0):
# sqft        9.251859e-17
# bedrooms   -9.251859e-17
# age         9.251859e-18
# dtype: float64
#
# Standard Deviations (should be ≈ 1):
# sqft        1.095445
# bedrooms    1.095445
# age         1.095445
# dtype: float64

# %% [markdown]
# ## Normalization vs Standardization
#
# Let's compare both techniques side by side to understand when to use each.

# %%
# Create data with an outlier
data_with_outlier = np.array([10, 12, 15, 14, 13, 11, 100])  # 100 is an outlier

# Apply both transformations
normalized = (data_with_outlier - data_with_outlier.min()) / (data_with_outlier.max() - data_with_outlier.min())
standardized = (data_with_outlier - data_with_outlier.mean()) / data_with_outlier.std()

comparison = pd.DataFrame({
    'Original': data_with_outlier,
    'Normalized': normalized,
    'Standardized': standardized
})

print(comparison)
# Out:
#    Original  Normalized  Standardized
# 0        10    0.000000     -0.489246
# 1        12    0.022222     -0.424013
# 2        15    0.055556     -0.326164
# 3        14    0.044444     -0.358780
# 4        13    0.033333     -0.391397
# 5        11    0.011111     -0.456630
# 6       100    1.000000      2.446230

# %% [markdown]
# Visualize how outliers affect each technique differently.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Original
axes[0].scatter(range(len(data_with_outlier)), data_with_outlier, s=100, c='steelblue')
axes[0].set_title('Original Data\n(Outlier dominates)')
axes[0].set_ylabel('Value')

# Normalized
axes[1].scatter(range(len(normalized)), normalized, s=100, c='coral')
axes[1].set_title('Normalized [0, 1]\n(Outlier squashes normal values)')
axes[1].set_ylabel('Normalized Value')

# Standardized
axes[2].scatter(range(len(standardized)), standardized, s=100, c='green')
axes[2].set_title('Standardized (Z-Score)\n(Outlier preserved as extreme z-score)')
axes[2].set_ylabel('Z-Score')

for ax in axes:
    ax.set_xlabel('Sample Index')
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## When to Use Standardization
#
# **Best for:**
# - Algorithms that assume normally distributed data (Linear/Logistic Regression, LDA)
# - When you want to preserve outlier information
# - PCA and other algorithms sensitive to variance
# - SVM with RBF kernel
#
# **Key difference:** Unlike normalization, standardization doesn't bound values to a specific range—it just centers them around zero.

# %% [markdown]
# # 3. One-Hot Encoding
#
# ## The Categorical Data Problem
#
# Machine learning algorithms work with numbers, but real-world data often contains categories:
# - Colors: Red, Blue, Green
# - Cities: New York, London, Tokyo
# - Product Types: Electronics, Clothing, Food
#
# Simply assigning numbers (Red=1, Blue=2, Green=3) is problematic because it implies ordering and distance that don't exist. One-hot encoding solves this elegantly.

# %% [markdown]
# ## How One-Hot Encoding Works
#
# For each unique category, create a new binary (0/1) column:
#
# | Original | → | is_Red | is_Blue | is_Green |
# |----------|---|--------|---------|----------|
# | Red      | → |   1    |    0    |    0     |
# | Blue     | → |   0    |    1    |    0     |
# | Green    | → |   0    |    0    |    1     |
#
# Each row has exactly one '1' (hence "one-hot"), indicating which category it belongs to.

# %% [markdown]
# ## Simple Example: Fruit Types
#
# Let's encode fruit types into one-hot vectors.

# %%
# Sample fruit data
fruits = np.array(['Apple', 'Banana', 'Apple', 'Cherry', 'Banana', 'Cherry', 'Apple'])

print("Original categorical data:")
print(fruits)
print(f"\nUnique categories: {np.unique(fruits)}")
# Out:
# Original categorical data:
# ['Apple' 'Banana' 'Apple' 'Cherry' 'Banana' 'Cherry' 'Apple']
#
# Unique categories: ['Apple' 'Banana' 'Cherry']

# %% [markdown]
# Manual one-hot encoding to understand the concept.

# %%
# Manual one-hot encoding
unique_fruits = np.unique(fruits)
one_hot_manual = np.zeros((len(fruits), len(unique_fruits)), dtype=int)

for i, fruit in enumerate(fruits):
    col_idx = np.where(unique_fruits == fruit)[0][0]
    one_hot_manual[i, col_idx] = 1

one_hot_df = pd.DataFrame(one_hot_manual, columns=[f'is_{fruit}' for fruit in unique_fruits])
one_hot_df.insert(0, 'Original', fruits)

print("One-Hot Encoded:")
print(one_hot_df)
# Out:
# One-Hot Encoded:
#   Original  is_Apple  is_Banana  is_Cherry
# 0    Apple         1          0          0
# 1   Banana         0          1          0
# 2    Apple         1          0          0
# 3   Cherry         0          0          1
# 4   Banana         0          1          0
# 5   Cherry         0          0          1
# 6    Apple         1          0          0

# %% [markdown]
# ## Using pandas get_dummies
#
# Pandas provides a convenient function for one-hot encoding.

# %%
# Create a simple DataFrame
df = pd.DataFrame({
    'fruit': ['Apple', 'Banana', 'Cherry'],
    'color': ['Red', 'Yellow', 'Red'],
    'price': [1.2, 0.5, 2.0]
})

print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#     fruit   color  price
# 0   Apple     Red    1.2
# 1  Banana  Yellow    0.5
# 2  Cherry     Red    2.0

# %% [markdown]
# Apply get_dummies to encode all categorical columns at once.

# %%
# One-hot encode with pandas
df_encoded = pd.get_dummies(df, columns=['fruit', 'color'])

print("\nOne-Hot Encoded DataFrame:")
print(df_encoded)
# Out:
# One-Hot Encoded DataFrame:
#    price  fruit_Apple  fruit_Banana  fruit_Cherry  color_Red  color_Yellow
# 0    1.2         True         False         False       True         False
# 1    0.5        False          True         False      False          True
# 2    2.0        False         False          True       True         False

# %% [markdown]
# ## Using sklearn OneHotEncoder
#
# For production pipelines, sklearn's encoder is more robust and handles new categories.

# %%
# Training data
train_colors = np.array(['Red', 'Blue', 'Green', 'Red', 'Blue']).reshape(-1, 1)

# Fit encoder on training data
encoder = OneHotEncoder(sparse_output=False)
encoder.fit(train_colors)

print("Categories learned:")
print(encoder.categories_[0])
print(f"\nFeature names:")
print(encoder.get_feature_names_out())
# Out:
# Categories learned:
# ['Blue' 'Green' 'Red']
#
# Feature names:
# ['x0_Blue' 'x0_Green' 'x0_Red']

# %% [markdown]
# Transform both training and new test data using the fitted encoder.

# %%
# Transform training data
train_encoded = encoder.transform(train_colors)

print("Training data encoded:")
train_df = pd.DataFrame(train_encoded, columns=encoder.get_feature_names_out())
train_df.insert(0, 'Original', train_colors.flatten())
print(train_df)
# Out:
# Training data encoded:
#   Original  x0_Blue  x0_Green  x0_Red
# 0      Red      0.0       0.0     1.0
# 1     Blue      1.0       0.0     0.0
# 2    Green      0.0       1.0     0.0
# 3      Red      0.0       0.0     1.0
# 4     Blue      1.0       0.0     0.0

# %% [markdown]
# ## Handling Unknown Categories
#
# What happens when test data contains categories not seen during training?

# %%
# Create encoder that handles unknown categories
encoder_safe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoder_safe.fit(train_colors)

# Test data with unknown category
test_colors = np.array(['Red', 'Yellow', 'Blue']).reshape(-1, 1)  # 'Yellow' is new!
test_encoded = encoder_safe.transform(test_colors)

print("Test data with unknown category:")
test_df = pd.DataFrame(test_encoded, columns=encoder_safe.get_feature_names_out())
test_df.insert(0, 'Original', test_colors.flatten())
print(test_df)
print("\nNote: 'Yellow' (unknown) is encoded as all zeros")
# Out:
# Test data with unknown category:
#   Original  x0_Blue  x0_Green  x0_Red
# 0      Red      0.0       0.0     1.0
# 1   Yellow      0.0       0.0     0.0
# 2     Blue      1.0       0.0     0.0
#
# Note: 'Yellow' (unknown) is encoded as all zeros

# %% [markdown]
# ## Visualizing One-Hot Encoding
#
# See the transformation from categorical to binary representation visually.

# %%
# Create sample data for visualization
categories = ['Cat', 'Dog', 'Bird', 'Cat', 'Dog', 'Cat', 'Bird', 'Dog']
cat_encoded = pd.get_dummies(pd.Series(categories))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Original categories as numbers (wrong approach)
cat_numbers = [0 if c == 'Cat' else 1 if c == 'Dog' else 2 for c in categories]
ax1.scatter(range(len(cat_numbers)), cat_numbers, s=200, c='red', alpha=0.6)
ax1.set_yticks([0, 1, 2])
ax1.set_yticklabels(['Cat', 'Dog', 'Bird'])
ax1.set_xlabel('Sample Index')
ax1.set_title('❌ Wrong: Ordinal Encoding\n(implies Dog > Cat > Bird)')
ax1.grid(True, alpha=0.3)

# One-hot encoding (correct approach)
sns.heatmap(cat_encoded.T, annot=True, fmt='d', cmap='RdYlGn', cbar=False, ax=ax2)
ax2.set_xlabel('Sample Index')
ax2.set_ylabel('Category')
ax2.set_title('✓ Correct: One-Hot Encoding\n(no implied ordering)')

plt.tight_layout()
plt.show()
# Out:
# /home/tsilva/repos/tsilva/aiml-notebooks/.venv/lib/python3.11/site-packages/seaborn/utils.py:61: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/tsilva/repos/tsilva/aiml-notebooks/.venv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## The Dummy Variable Trap
#
# When using linear models, you can drop one category to avoid multicollinearity (the dummy variable trap). If you know all other categories are 0, you automatically know the dropped category is 1.

# %%
# With drop_first=True, one category is dropped
df_dummy_trap = pd.get_dummies(pd.Series(['Red', 'Blue', 'Green']), drop_first=True)

print("One-Hot with drop_first=True:")
print(df_dummy_trap)
print("\nRed is the reference category (all zeros means Red)")
# Out:
# One-Hot with drop_first=True:
#    Green    Red
# 0  False   True
# 1  False  False
# 2   True  False
#
# Red is the reference category (all zeros means Red)

# %% [markdown]
# ## When to Use One-Hot Encoding
#
# **Best for:**
# - Nominal categories (no natural order): colors, cities, product types
# - Small number of unique categories (< 10-20)
# - Tree-based models (Random Forest, XGBoost)
# - Neural networks
#
# **Limitations:**
# - High cardinality (many unique values) creates too many columns
# - Sparse data (mostly zeros) increases memory usage
#
# **Alternatives for high cardinality:**
# - Target encoding
# - Embeddings (for neural networks)

# %% [markdown]
# # 4. Binning (Discretization)
#
# ## Why Bin Continuous Data?
#
# Binning groups continuous values into discrete intervals. This can:
# - Reduce the impact of minor observation errors
# - Handle outliers more gracefully
# - Introduce non-linearity to linear models
# - Make relationships easier to interpret
#
# Example: Converting exact ages (23, 45, 67) into age groups (18-30, 31-50, 51-70).

# %% [markdown]
# ## Two Main Binning Strategies
#
# 1. **Equal-Width Binning**: Divide the range into bins of equal size
#    - Example: 0-25, 25-50, 50-75, 75-100
#
# 2. **Equal-Frequency Binning**: Divide data so each bin has roughly the same number of samples
#    - Example: First quartile, second quartile, etc.
#
# Each has different use cases depending on your data distribution.

# %% [markdown]
# ## Example Dataset: Customer Ages
#
# Create a sample dataset of customer ages to demonstrate binning.

# %%
# Generate sample age data (skewed distribution)
np.random.seed(42)
ages = np.concatenate([
    np.random.normal(25, 3, 40),   # Young adults
    np.random.normal(45, 5, 30),   # Middle-aged
    np.random.normal(70, 4, 20)    # Seniors
])
ages = np.clip(ages, 18, 85)  # Realistic age bounds

print(f"Number of samples: {len(ages)}")
print(f"Age range: {ages.min():.1f} - {ages.max():.1f}")
print(f"Mean age: {ages.mean():.1f}")
# Out:
# Number of samples: 90
# Age range: 19.1 - 76.3
# Mean age: 41.4

# %% [markdown]
# Visualize the distribution of ages to understand what we're working with.

# %%
plt.figure(figsize=(10, 5))
plt.hist(ages, bins=20, color='steelblue', alpha=0.7, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Customer Ages')
plt.axvline(ages.mean(), color='red', linestyle='--', linewidth=2, label=f'Mean = {ages.mean():.1f}')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Equal-Width Binning
#
# Divide the age range into bins of equal width using pandas.cut().

# %%
# Equal-width binning into 4 bins
ages_binned_width = pd.cut(ages, bins=4)

print("Equal-Width Bins:")
print(ages_binned_width.value_counts().sort_index())
print(f"\nBin intervals: {ages_binned_width.categories.tolist()}")
# Out:
# Equal-Width Bins:
# (19.064, 33.405]    40
# (33.405, 47.69]     21
# (47.69, 61.974]     10
# (61.974, 76.259]    19
# Name: count, dtype: int64
#
# Bin intervals: [Interval(19.064, 33.405, closed='right'), Interval(33.405, 47.69, closed='right'), Interval(47.69, 61.974, closed='right'), Interval(61.974, 76.259, closed='right')]

# %% [markdown]
# Apply custom labels to make the bins more interpretable.

# %%
# Custom bins with labels
bins = [18, 30, 45, 60, 85]
labels = ['Young Adult', 'Adult', 'Middle-Aged', 'Senior']
ages_categorized = pd.cut(ages, bins=bins, labels=labels)

print("Custom Age Categories:")
print(ages_categorized.value_counts())
# Out:
# Custom Age Categories:
# Young Adult    39
# Adult          17
# Middle-Aged    15
# Senior         19
# Name: count, dtype: int64

# %% [markdown]
# ## Equal-Frequency Binning (Quantiles)
#
# Divide data into bins with approximately equal number of samples using pandas.qcut().

# %%
# Equal-frequency binning (quartiles)
ages_binned_freq = pd.qcut(ages, q=4)

print("Equal-Frequency Bins (Quartiles):")
print(ages_binned_freq.value_counts().sort_index())
print(f"\nNote: Each bin has approximately {len(ages)//4} samples")
# Out:
# Equal-Frequency Bins (Quartiles):
# (19.119999999999997, 24.679]    23
# (24.679, 41.102]                22
# (41.102, 50.121]                22
# (50.121, 76.259]                23
# Name: count, dtype: int64
#
# Note: Each bin has approximately 22 samples

# %% [markdown]
# Apply custom labels to quantile bins.

# %%
# Quantile binning with labels
ages_quantiles = pd.qcut(ages, q=4, labels=['Q1', 'Q2', 'Q3', 'Q4'])

print("Age Quartiles:")
print(ages_quantiles.value_counts())
# Out:
# Age Quartiles:
# Q1    23
# Q2    22
# Q3    22
# Q4    23
# Name: count, dtype: int64

# %% [markdown]
# ## Comparing Binning Strategies
#
# Visualize how equal-width and equal-frequency binning differ on the same data.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Equal-width binning visualization
ages_width_codes = pd.cut(ages, bins=4).codes
ax1.hist(ages, bins=20, alpha=0.3, color='gray', label='Original distribution')
for i, interval in enumerate(pd.cut(ages, bins=4).categories):
    mask = ages_width_codes == i
    ax1.hist(ages[mask], bins=20, alpha=0.6, label=f'Bin {i+1}')
ax1.set_xlabel('Age')
ax1.set_ylabel('Frequency')
ax1.set_title('Equal-Width Binning\n(Bins have equal width but different counts)')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Equal-frequency binning visualization
ages_freq_codes = pd.qcut(ages, q=4).codes
ax2.hist(ages, bins=20, alpha=0.3, color='gray', label='Original distribution')
for i, interval in enumerate(pd.qcut(ages, q=4).categories):
    mask = ages_freq_codes == i
    ax2.hist(ages[mask], bins=20, alpha=0.6, label=f'Bin {i+1}')
ax2.set_xlabel('Age')
ax2.set_ylabel('Frequency')
ax2.set_title('Equal-Frequency Binning\n(Bins have different widths but similar counts)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# Create a detailed comparison table showing the characteristics of each binning strategy.

# %%
# Comparison statistics
width_bins = pd.cut(ages, bins=4)
freq_bins = pd.qcut(ages, q=4)

comparison_df = pd.DataFrame({
    'Strategy': ['Equal-Width'] * 4 + ['Equal-Frequency'] * 4,
    'Bin': list(width_bins.categories) + list(freq_bins.categories),
    'Count': list(width_bins.value_counts().sort_index()) + list(freq_bins.value_counts().sort_index()),
    'Width': [interval.length for interval in width_bins.categories] + 
             [interval.length for interval in freq_bins.categories]
})

print("Binning Strategy Comparison:")
print(comparison_df.to_string(index=False))
# Out:
# Binning Strategy Comparison:
#        Strategy                          Bin  Count  Width
#     Equal-Width             (19.064, 33.405]     40 14.341
#     Equal-Width              (33.405, 47.69]     21 14.285
#     Equal-Width              (47.69, 61.974]     10 14.284
#     Equal-Width             (61.974, 76.259]     19 14.285
# Equal-Frequency (19.119999999999997, 24.679]     23  5.559
# Equal-Frequency             (24.679, 41.102]     22 16.423
# Equal-Frequency             (41.102, 50.121]     22  9.019
# Equal-Frequency             (50.121, 76.259]     23 26.138

# %% [markdown]
# ## Converting Bins to Numeric Features
#
# After binning, you can use the bins in different ways depending on your model.

# %%
# Create a DataFrame with original and binned ages
age_df = pd.DataFrame({'age': ages})
age_df['age_category'] = pd.cut(ages, bins=bins, labels=labels)

# Option 1: Use bin labels as ordinal encoding
age_df['age_ordinal'] = age_df['age_category'].cat.codes

# Option 2: One-hot encode the bins
age_one_hot = pd.get_dummies(age_df['age_category'], prefix='age')
age_df_encoded = pd.concat([age_df, age_one_hot], axis=1)

print("Sample of encoded age data:")
print(age_df_encoded.head(10))
# Out:
# Sample of encoded age data:
#          age age_category  age_ordinal  age_Young Adult  age_Adult  \
# 0  26.490142  Young Adult            0             True      False
# 1  24.585207  Young Adult            0             True      False
# 2  26.943066  Young Adult            0             True      False
# 3  29.569090  Young Adult            0             True      False
# 4  24.297540  Young Adult            0             True      False
# 5  24.297589  Young Adult            0             True      False
# 6  29.737638  Young Adult            0             True      False
# 7  27.302304  Young Adult            0             True      False
# 8  23.591577  Young Adult            0             True      False
# 9  26.627680  Young Adult            0             True      False
#
#    age_Middle-Aged  age_Senior
# 0            False       False
# 1            False       False
# 2            False       False
# 3            False       False
# 4            False       False
# 5            False       False
# 6            False       False
# 7            False       False
# 8            False       False
# 9            False       False

# %% [markdown]
# ## When to Use Binning
#
# **Equal-Width Binning:**
# - When you want intuitive, evenly-spaced intervals
# - For visualizations and reporting
# - When data is uniformly distributed
#
# **Equal-Frequency Binning:**
# - When data is skewed or has outliers
# - When you want balanced classes
# - For percentile-based analysis
#
# **General use cases:**
# - Converting continuous features for decision trees
# - Creating age/income groups for analysis
# - Handling non-linear relationships in linear models
# - Reducing the impact of outliers

# %% [markdown]
# # 5. Putting It All Together
#
# ## Real-World Feature Engineering Pipeline
#
# Let's apply multiple techniques to a realistic dataset. We'll create synthetic customer data and prepare it for machine learning.

# %%
# Create synthetic customer dataset
np.random.seed(42)
n_customers = 100

customer_data = pd.DataFrame({
    'age': np.random.randint(18, 75, n_customers),
    'income': np.random.normal(50000, 20000, n_customers),
    'spending_score': np.random.randint(1, 100, n_customers),
    'country': np.random.choice(['USA', 'UK', 'Germany', 'France'], n_customers),
    'membership': np.random.choice(['Bronze', 'Silver', 'Gold'], n_customers)
})

# Clip income to realistic values
customer_data['income'] = customer_data['income'].clip(20000, 150000)

print("Raw Customer Data (first 5 rows):")
print(customer_data.head())
print(f"\nShape: {customer_data.shape}")
print(f"\nData types:\n{customer_data.dtypes}")
# Out:
# Raw Customer Data (first 5 rows):
#    age        income  spending_score country membership
# 0   56  96814.926682              39  France       Gold
# 1   69  71419.703740              82     USA     Bronze
# 2   46  51928.329581               1     USA     Bronze
# 3   32  58382.042112              11  France     Bronze
# 4   60  30939.444216              92     USA     Bronze
#
# Shape: (100, 5)
#
# Data types:
# age                 int64
# income            float64
# spending_score      int64
# country            object
# membership         object
# dtype: object

# %% [markdown]
# ## Step 1: Bin the Age Feature
#
# Convert continuous age into meaningful age groups.

# %%
# Bin age into groups
age_bins = [18, 30, 45, 60, 75]
age_labels = ['Young', 'Adult', 'Middle-Aged', 'Senior']
customer_data['age_group'] = pd.cut(customer_data['age'], bins=age_bins, labels=age_labels)

print("Age group distribution:")
print(customer_data['age_group'].value_counts().sort_index())
# Out:
# Age group distribution:
# age_group
# Young          21
# Adult          33
# Middle-Aged    21
# Senior         25
# Name: count, dtype: int64

# %% [markdown]
# ## Step 2: Normalize Numerical Features
#
# Scale income and spending_score to [0, 1] range.

# %%
# Select numerical features for normalization
numerical_features = ['income', 'spending_score']

# Normalize using MinMaxScaler
scaler = MinMaxScaler()
customer_data[['income_norm', 'spending_norm']] = scaler.fit_transform(customer_data[numerical_features])

print("Before and after normalization:")
print(customer_data[['income', 'income_norm', 'spending_score', 'spending_norm']].head())
# Out:
# Before and after normalization:
#          income  income_norm  spending_score  spending_norm
# 0  96814.926682     0.864320              39       0.387755
# 1  71419.703740     0.578573              82       0.826531
# 2  51928.329581     0.359257               1       0.000000
# 3  58382.042112     0.431874              11       0.102041
# 4  30939.444216     0.123090              92       0.928571

# %% [markdown]
# ## Step 3: One-Hot Encode Categorical Features
#
# Convert country and age_group into binary features.

# %%
# One-hot encode categorical features
customer_encoded = pd.get_dummies(
    customer_data,
    columns=['country', 'age_group', 'membership'],
    prefix=['country', 'age', 'member']
)

print(f"Shape after encoding: {customer_encoded.shape}")
print(f"\nNew columns created:")
new_cols = [col for col in customer_encoded.columns if col not in customer_data.columns]
print(new_cols)
# Out:
# Shape after encoding: (100, 16)
#
# New columns created:
# ['country_France', 'country_Germany', 'country_UK', 'country_USA', 'age_Young', 'age_Adult', 'age_Middle-Aged', 'age_Senior', 'member_Bronze', 'member_Gold', 'member_Silver']

# %% [markdown]
# ## Step 4: Create Final Feature Matrix
#
# Select only the engineered features for modeling, dropping original raw features.

# %%
# Select final features for modeling
feature_columns = ['income_norm', 'spending_norm'] + new_cols
X = customer_encoded[feature_columns]

print("Final feature matrix:")
print(X.head())
print(f"\nFinal shape: {X.shape}")
print(f"Features: {X.columns.tolist()}")
# Out:
# Final feature matrix:
#    income_norm  spending_norm  country_France  country_Germany  country_UK  \
# 0     0.864320       0.387755            True            False       False
# 1     0.578573       0.826531           False            False       False
# 2     0.359257       0.000000           False            False       False
# 3     0.431874       0.102041            True            False       False
# 4     0.123090       0.928571           False            False       False
#
#    country_USA  age_Young  age_Adult  age_Middle-Aged  age_Senior  \
# 0        False      False      False             True       False
# 1         True      False      False            False        True
# 2         True      False      False             True       False
# 3        False      False       True            False       False
# 4         True      False      False             True       False
#
#    member_Bronze  member_Gold  member_Silver
# 0          False         True          False
# 1           True        False          False
# 2           True        False          False
# 3           True        False          False
# 4           True        False          False
#
# Final shape: (100, 13)
# Features: ['income_norm', 'spending_norm', 'country_France', 'country_Germany', 'country_UK', 'country_USA', 'age_Young', 'age_Adult', 'age_Middle-Aged', 'age_Senior', 'member_Bronze', 'member_Gold', 'member_Silver']

# %% [markdown]
# ## Visualize the Feature Engineering Pipeline
#
# Compare the raw data distribution with the engineered features.

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Original income distribution
axes[0, 0].hist(customer_data['income'], bins=20, color='steelblue', alpha=0.7, edgecolor='black')
axes[0, 0].set_xlabel('Income ($)')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Original Income Distribution')

# Normalized income distribution
axes[0, 1].hist(customer_data['income_norm'], bins=20, color='coral', alpha=0.7, edgecolor='black')
axes[0, 1].set_xlabel('Normalized Income')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('Normalized Income [0, 1]')

# Age group distribution
age_counts = customer_data['age_group'].value_counts().sort_index()
axes[1, 0].bar(range(len(age_counts)), age_counts.values, color='green', alpha=0.7)
axes[1, 0].set_xticks(range(len(age_counts)))
axes[1, 0].set_xticklabels(age_counts.index, rotation=45)
axes[1, 0].set_ylabel('Count')
axes[1, 0].set_title('Age Groups (After Binning)')

# Country one-hot encoding sample
country_cols = [col for col in X.columns if col.startswith('country_')]
sample_countries = X[country_cols].head(10)
sns.heatmap(sample_countries.T, annot=True, fmt='d', cmap='RdYlGn', cbar=False, ax=axes[1, 1])
axes[1, 1].set_xlabel('Customer Index')
axes[1, 1].set_title('Country One-Hot Encoding (First 10 Customers)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary Statistics
#
# Compare the feature space before and after engineering.

# %%
print("=" * 60)
print("FEATURE ENGINEERING SUMMARY")
print("=" * 60)
print(f"\nOriginal dataset:")
print(f"  - Shape: {customer_data.shape}")
print(f"  - Numerical features: {len(numerical_features)}")
print(f"  - Categorical features: 3 (country, age_group, membership)")
print(f"\nEngineered dataset:")
print(f"  - Shape: {X.shape}")
print(f"  - All features normalized/encoded and ready for ML")
print(f"  - Features created: {X.shape[1]}")
print(f"\nTransformations applied:")
print(f"  1. Binning: age → age_group (4 categories)")
print(f"  2. Normalization: income, spending_score → [0, 1] range")
print(f"  3. One-hot encoding: country, age_group, membership → binary features")
print("\n" + "=" * 60)
# Out:
# ============================================================
# FEATURE ENGINEERING SUMMARY
# ============================================================
#
# Original dataset:
#   - Shape: (100, 8)
#   - Numerical features: 2
#   - Categorical features: 3 (country, age_group, membership)
#
# Engineered dataset:
#   - Shape: (100, 13)
#   - All features normalized/encoded and ready for ML
#   - Features created: 13
#
# Transformations applied:
#   1. Binning: age → age_group (4 categories)
#   2. Normalization: income, spending_score → [0, 1] range
#   3. One-hot encoding: country, age_group, membership → binary features
#
# ============================================================

# %% [markdown]
# # Key Takeaways
#
# ## When to Use Each Technique
#
# | Technique | Use Case | Best For |
# |-----------|----------|----------|
# | **Normalization** | Scale to [0, 1] | Neural networks, distance-based algorithms, bounded ranges |
# | **Standardization** | Zero mean, unit variance | Algorithms assuming normal distribution, preserving outliers |
# | **One-Hot Encoding** | Categorical → Binary | Nominal categories, tree-based models, neural networks |
# | **Binning** | Continuous → Discrete | Age/income groups, handling outliers, creating non-linearity |
#
# ## Feature Engineering Best Practices
#
# 1. **Always split first**: Fit transformations on training data only, then apply to test data
# 2. **Handle missing values**: Before scaling or encoding
# 3. **Understand your algorithm**: Different models need different preprocessing
# 4. **Keep it interpretable**: Complex features are harder to explain to stakeholders
# 5. **Pipeline it**: Use sklearn's Pipeline for reproducible transformations
# 6. **Monitor distributions**: Visualize before and after transformations
#
# ## Common Pitfalls to Avoid
#
# - ❌ Fitting scalers on test data (data leakage)
# - ❌ Applying normalization when standardization is needed (and vice versa)
# - ❌ One-hot encoding high cardinality features (too many columns)
# - ❌ Forgetting to handle unknown categories in test data
# - ❌ Not documenting which transformations were applied
#
# Feature engineering is both art and science—experiment with different techniques and let your model performance guide you!
