# %% [markdown]
# <a href="https://colab.research.google.com/github/tsilva/aiml-notebooks/blob/main/notebooks/wip-rl-lunarlander-a2c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install tsilva-notebook-utils # Personal utils to help with notebook authoring
# Out:
# Requirement already satisfied: swig in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (4.3.1)
# Requirement already satisfied: gymnasium[box2d] in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from gymnasium[box2d]) (2.2.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from gymnasium[box2d]) (4.3.1)
# Requirement already satisfied: tsilva-notebook-utils in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (0.0.88)
# Requirement already satisfied: bokeh in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (3.7.3)
# Requirement already satisfied: datasets in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (3.2.0)
# Requirement already satisfied: huggingface-hub in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (0.28.0)
# Requirement already satisfied: imageio>=2.0.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (2.37.0)
# Requirement already satisfied: ipython>=7.0.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (8.32.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (2.2.2)
# Requirement already satisfied: opencv-python>=4.0.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (4.11.0.86)
# Requirement already satisfied: pynvml in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (12.0.0)
# Requirement already satisfied: python-dotenv in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (1.0.1)
# Requirement already satisfied: pytorch-lightning in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (2.5.1.post0)
# Requirement already satisfied: scikit-learn in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (1.6.1)
# Requirement already satisfied: tqdm>=4.0.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from tsilva-notebook-utils) (4.67.1)
# Requirement already satisfied: pillow>=8.3.2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from imageio>=2.0.0->tsilva-notebook-utils) (11.1.0)
# Requirement already satisfied: decorator in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (2.19.1)
# Requirement already satisfied: stack_data in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from ipython>=7.0.0->tsilva-notebook-utils) (4.12.2)
# Requirement already satisfied: Jinja2>=2.9 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (3.1.5)
# Requirement already satisfied: contourpy>=1.2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (1.3.1)
# Requirement already satisfied: narwhals>=1.13 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (1.39.0)
# Requirement already satisfied: packaging>=16.8 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (24.2)
# Requirement already satisfied: pandas>=1.2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (2.2.3)
# Requirement already satisfied: PyYAML>=3.10 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from bokeh->tsilva-notebook-utils) (2025.4.0)
# Requirement already satisfied: filelock in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from datasets->tsilva-notebook-utils) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from datasets->tsilva-notebook-utils) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from datasets->tsilva-notebook-utils) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from datasets->tsilva-notebook-utils) (2.32.3)
# Requirement already satisfied: xxhash in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from datasets->tsilva-notebook-utils) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from datasets->tsilva-notebook-utils) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->tsilva-notebook-utils) (2024.9.0)
# Requirement already satisfied: aiohttp in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from datasets->tsilva-notebook-utils) (3.11.11)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pynvml->tsilva-notebook-utils) (12.575.51)
# Requirement already satisfied: torch>=2.1.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pytorch-lightning->tsilva-notebook-utils) (2.5.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pytorch-lightning->tsilva-notebook-utils) (1.7.1)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pytorch-lightning->tsilva-notebook-utils) (0.14.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from scikit-learn->tsilva-notebook-utils) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from scikit-learn->tsilva-notebook-utils) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from scikit-learn->tsilva-notebook-utils) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from aiohttp->datasets->tsilva-notebook-utils) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from aiohttp->datasets->tsilva-notebook-utils) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from aiohttp->datasets->tsilva-notebook-utils) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from aiohttp->datasets->tsilva-notebook-utils) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from aiohttp->datasets->tsilva-notebook-utils) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from aiohttp->datasets->tsilva-notebook-utils) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from aiohttp->datasets->tsilva-notebook-utils) (1.18.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.0.0->tsilva-notebook-utils) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh->tsilva-notebook-utils) (3.0.2)
# Requirement already satisfied: setuptools in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning->tsilva-notebook-utils) (75.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pandas>=1.2->bokeh->tsilva-notebook-utils) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pandas>=1.2->bokeh->tsilva-notebook-utils) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pandas>=1.2->bokeh->tsilva-notebook-utils) (2025.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.0.0->tsilva-notebook-utils) (0.7.0)
# Requirement already satisfied: wcwidth in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.0.0->tsilva-notebook-utils) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from requests>=2.32.2->datasets->tsilva-notebook-utils) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from requests>=2.32.2->datasets->tsilva-notebook-utils) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from requests>=2.32.2->datasets->tsilva-notebook-utils) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from requests>=2.32.2->datasets->tsilva-notebook-utils) (2024.12.14)
# Requirement already satisfied: sympy==1.13.1 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from torch>=2.1.0->pytorch-lightning->tsilva-notebook-utils) (1.13.1)
# Requirement already satisfied: networkx in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from torch>=2.1.0->pytorch-lightning->tsilva-notebook-utils) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from sympy==1.13.1->torch>=2.1.0->pytorch-lightning->tsilva-notebook-utils) (1.3.0)
# Requirement already satisfied: executing>=1.2.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from stack_data->ipython>=7.0.0->tsilva-notebook-utils) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from stack_data->ipython>=7.0.0->tsilva-notebook-utils) (3.0.0)
# Requirement already satisfied: pure_eval in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from stack_data->ipython>=7.0.0->tsilva-notebook-utils) (0.2.3)
# Requirement already satisfied: six>=1.5 in /home/tsilva/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh->tsilva-notebook-utils) (1.17.0)

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical
import matplotlib.pyplot as plt
from collections import deque

# Hyperparameters (updated based on your input)
GAMMA = 0.995          # From gamma: 0.995
LEARNING_RATE = 0.00083  # From learning_rate: lin_0.00083 (assuming linear schedule starts here)
ENTROPY_COEFF = 0.00001  # From ent_coef: 0.00001
MAX_EPISODES = 10_000
SOLVED_SCORE = 200
VALUE_COEFF = 0.5
HIDDEN_LAYER = 256
TOTAL_TIMESTEPS_LIMIT = int(2e5)  # From n_timesteps: 2e5 (we'll use this as a stopping condition)

# Unused from your list:
# - n_envs: 8 (requires vectorized environments, not implemented here)
# - n_steps: 5 (specific to PPO rollout buffers, not applicable here)
# - policy: 'MlpPolicy' (implies an MLP, which we already have)

# Device configuration
DEVICE = "cpu"  # Change to "cuda" if available and desired
print(f"Using device: {DEVICE}")

class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.fc1 = nn.Linear(state_dim, HIDDEN_LAYER)
        self.fc2 = nn.Linear(HIDDEN_LAYER, HIDDEN_LAYER)
        self.actor = nn.Linear(HIDDEN_LAYER, action_dim)
        self.critic = nn.Linear(HIDDEN_LAYER, 1)

        for layer in self.modules():
            if isinstance(layer, nn.Linear):
                nn.init.orthogonal_(layer.weight, gain=np.sqrt(2))
                layer.bias.data.zero_()

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        action_probs = F.softmax(self.actor(x), dim=-1)
        state_value = self.critic(x)
        return action_probs, state_value

def train(model):
    # Note: Using LunarLander-v3 as in original code (not v2 as in your hyperparams)
    env = gym.make("LunarLander-v3")
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n
    model = ActorCritic(state_dim, action_dim).to(DEVICE)

    model.train()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    scores = []
    avg_scores = []
    recent_scores = deque(maxlen=100)
    timesteps_history = []
    total_timesteps = 0

    for episode in range(1, MAX_EPISODES + 1):
        state, _ = env.reset()
        score = 0
        done = False
        episode_timesteps = 0

        states = []
        actions = []
        rewards = []
        dones = []

        while not done:
            state_tensor = torch.FloatTensor(state).unsqueeze(0).to(DEVICE)

            with torch.no_grad():
                action_probs, state_value = model(state_tensor)

            dist = Categorical(action_probs)
            action = dist.sample().item()

            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            states.append(state)
            actions.append(action)
            rewards.append(reward)
            dones.append(done)

            state = next_state
            score += reward
            episode_timesteps += 1
            total_timesteps += 1

            # Check total timestep limit
            #if total_timesteps >= TOTAL_TIMESTEPS_LIMIT:
            #    print(f"\nReached total timestep limit of {TOTAL_TIMESTEPS_LIMIT}")
            #    break

        #if total_timesteps >= TOTAL_TIMESTEPS_LIMIT:
        #    break

        # Training logic
        states_tensor = torch.FloatTensor(np.array(states)).to(DEVICE)
        actions_tensor = torch.LongTensor(actions).to(DEVICE)
        action_probs, state_values = model(states_tensor)
        state_values = state_values.squeeze()

        dist = Categorical(action_probs)
        log_probs = dist.log_prob(actions_tensor)
        entropy = dist.entropy().mean()

        returns = []
        discounted_reward = 0
        for reward, done in zip(reversed(rewards), reversed(dones)):
            if done:
                discounted_reward = 0
            discounted_reward = reward + GAMMA * discounted_reward
            returns.insert(0, discounted_reward)

        returns = torch.FloatTensor(returns).to(DEVICE)
        returns = (returns - returns.mean()) / (returns.std() + 1e-8)
        advantage = returns - state_values.detach()

        actor_loss = -(log_probs * advantage).mean()
        critic_loss = VALUE_COEFF * F.mse_loss(state_values, returns)
        entropy_loss = -ENTROPY_COEFF * entropy
        loss = actor_loss + critic_loss + entropy_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        scores.append(score)
        recent_scores.append(score)
        avg_score = np.mean(recent_scores)
        avg_scores.append(avg_score)
        timesteps_history.append(episode_timesteps)

        if episode % 10 == 0:
            print(f"Episode {episode}, Score: {score:.2f}, Avg Score (100): {avg_score:.2f}, "
                  f"Total Timesteps: {total_timesteps}, "
                  f"Loss: {loss.item():.4f}")

        if len(recent_scores) == 100 and avg_score >= SOLVED_SCORE:
            print(f"\nEnvironment solved in {episode} episodes!")
            print(f"Average Score: {avg_score:.2f}")
            print(f"Total Timesteps: {total_timesteps}")
            torch.save(model.state_dict(), 'lunar_lander_solved.pt')
            break

    # Plotting
    plt.figure(figsize=(12, 8))

    plt.subplot(2, 1, 1)
    plt.plot(scores, alpha=0.3, color='gray')
    plt.plot(avg_scores, color='blue', linewidth=2)
    plt.xlabel('Episode')
    plt.ylabel('Score')
    plt.title('Learning Curve')
    plt.axhline(y=200, color='r', linestyle='-', alpha=0.5)
    plt.text(len(scores)-100, 210, 'Solved Threshold')

    plt.subplot(2, 1, 2)
    plt.plot(timesteps_history, color='green', linewidth=2)
    plt.xlabel('Episode')
    plt.ylabel('Timesteps')
    plt.title('Timesteps per Episode')

    plt.tight_layout()
    plt.savefig('learning_curves.png')
    plt.show()

    print(f"\nTraining completed!")
    print(f"Total Episodes: {episode}")
    print(f"Total Timesteps: {total_timesteps}")

    return model

env = gym.make("LunarLander-v3")
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
model = ActorCritic(state_dim, action_dim).to(DEVICE)
train(model)
# Out:
# Using device: cpu
# Episode 10, Score: -128.67, Avg Score (100): -149.51, Total Timesteps: 938, Loss: 0.5971
# Episode 20, Score: -152.47, Avg Score (100): -200.76, Total Timesteps: 2057, Loss: 0.5782
# Episode 30, Score: -282.60, Avg Score (100): -197.65, Total Timesteps: 3067, Loss: 0.2794
# Episode 40, Score: -208.84, Avg Score (100): -197.74, Total Timesteps: 4087, Loss: 0.2800
# Episode 50, Score: -83.35, Avg Score (100): -185.73, Total Timesteps: 5030, Loss: 0.5723
# Episode 60, Score: -210.13, Avg Score (100): -183.19, Total Timesteps: 6160, Loss: 0.6034
# Episode 70, Score: -105.54, Avg Score (100): -175.05, Total Timesteps: 7145, Loss: 0.3599
# Episode 80, Score: -294.61, Avg Score (100): -169.49, Total Timesteps: 8178, Loss: 0.3499
# Episode 90, Score: -68.53, Avg Score (100): -164.61, Total Timesteps: 9206, Loss: 0.3197
# Episode 100, Score: -75.80, Avg Score (100): -163.77, Total Timesteps: 10596, Loss: 0.3825
# Episode 110, Score: -37.17, Avg Score (100): -160.95, Total Timesteps: 11865, Loss: 0.5865
# Episode 120, Score: -4.02, Avg Score (100): -143.87, Total Timesteps: 12964, Loss: 0.4078
# Episode 130, Score: -60.33, Avg Score (100): -135.99, Total Timesteps: 14324, Loss: 0.3850
# Episode 140, Score: -53.20, Avg Score (100): -127.74, Total Timesteps: 15401, Loss: 0.1670
# Episode 150, Score: -106.88, Avg Score (100): -125.87, Total Timesteps: 16629, Loss: 0.1238
# Episode 160, Score: -36.28, Avg Score (100): -115.00, Total Timesteps: 17695, Loss: 0.1969
# Episode 170, Score: -6.44, Avg Score (100): -108.50, Total Timesteps: 19204, Loss: 0.1588
# Episode 180, Score: -49.82, Avg Score (100): -100.00, Total Timesteps: 20638, Loss: -0.0219
# Episode 190, Score: -55.00, Avg Score (100): -94.07, Total Timesteps: 21982, Loss: 0.0663
# Episode 200, Score: -44.21, Avg Score (100): -81.59, Total Timesteps: 24204, Loss: -0.1832
# Episode 210, Score: -43.30, Avg Score (100): -76.88, Total Timesteps: 25865, Loss: 0.0837
# Episode 220, Score: -101.91, Avg Score (100): -72.10, Total Timesteps: 27370, Loss: -0.1003
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 188
#     186 action_dim = env.action_space.n
#     187 model = ActorCritic(state_dim, action_dim).to(DEVICE)
# --> 188 train(model)
#
# Cell In[6], line 136, in train(model)
#     134 optimizer.zero_grad()
#     135 loss.backward()
# --> 136 optimizer.step()
#     138 scores.append(score)
#     139 recent_scores.append(score)
#
# File ~/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages/torch/optim/optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     482         else:
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#     490 # call optimizer step post hooks
#
# File ~/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages/torch/optim/optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File ~/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages/torch/optim/adam.py:223, in Adam.step(self, closure)
#     211     beta1, beta2 = group["betas"]
#     213     has_complex = self._init_group(
#     214         group,
#     215         params_with_grad,
#    (...)
#     220         state_steps,
#     221     )
# --> 223     adam(
#     224         params_with_grad,
#     225         grads,
#     226         exp_avgs,
#     227         exp_avg_sqs,
#     228         max_exp_avg_sqs,
#     229         state_steps,
#     230         amsgrad=group["amsgrad"],
#     231         has_complex=has_complex,
#     232         beta1=beta1,
#     233         beta2=beta2,
#     234         lr=group["lr"],
#     235         weight_decay=group["weight_decay"],
#     236         eps=group["eps"],
#     237         maximize=group["maximize"],
#     238         foreach=group["foreach"],
#     239         capturable=group["capturable"],
#     240         differentiable=group["differentiable"],
#     241         fused=group["fused"],
#     242         grad_scale=getattr(self, "grad_scale", None),
#     243         found_inf=getattr(self, "found_inf", None),
#     244     )
#     246 return loss
#
# File ~/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages/torch/optim/optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages/torch/optim/adam.py:784, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     781 else:
#     782     func = _single_tensor_adam
# --> 784 func(
#     785     params,
#     786     grads,
#     787     exp_avgs,
#     788     exp_avg_sqs,
#     789     max_exp_avg_sqs,
#     790     state_steps,
#     791     amsgrad=amsgrad,
#     792     has_complex=has_complex,
#     793     beta1=beta1,
#     794     beta2=beta2,
#     795     lr=lr,
#     796     weight_decay=weight_decay,
#     797     eps=eps,
#     798     maximize=maximize,
#     799     capturable=capturable,
#     800     differentiable=differentiable,
#     801     grad_scale=grad_scale,
#     802     found_inf=found_inf,
#     803 )
#
# File ~/miniconda3/envs/aiml-notebooks/lib/python3.11/site-packages/torch/optim/adam.py:430, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     428         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     429     else:
# --> 430         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     432     param.addcdiv_(exp_avg, denom, value=-step_size)
#     434 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
from tsilva_notebook_utils.video import render_video_from_batches
from PIL import Image

def run_episode(model):
    # Create environment with rendering enabled
    env = gym.make("LunarLander-v3", render_mode="rgb_array")

    # Set model to evaluation mode
    model.eval()

    # Reset environment
    state, _ = env.reset()
    score = 0
    done = False

    # Run the episode
    frames = []
    while not done:
        # Render the environment and convert numpy array to PIL Image
        frame = env.render()
        pil_frame = Image.fromarray(frame)
        frames.append(pil_frame)

        # Convert state to tensor
        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(DEVICE)

        # Get action probabilities (no gradients needed)
        with torch.no_grad():
            action_probs, _ = model(state_tensor)

        # Sample action from the policy
        dist = Categorical(action_probs)
        action = dist.sample().item()

        # Take action in the environment
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        # Update state and score
        state = next_state
        score += reward

    # Close the environment
    env.close()

    print(f"Episode completed! Score: {score:.2f}")

    return score, frames

# Run a single episode with rendering
score, frames = run_episode(model)
render_video_from_batches(frames)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode completed! Score: -81.19
#         <video width="600" height="400" controls autoplay loop muted>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#             Your browser does not support the video tag.
#         </video>
